# %% [markdown]
# # Merge zarr files

# %%
import xarray as xr
import glob

# %%
files = glob.glob('/output/global/*.zarr')

# %%
files
# Out:
# ['/tmp/modis_snow_presence/tile_h17_v17.zarr',
#  '/tmp/modis_snow_presence/tile_h15_v17.zarr',
#  '/tmp/modis_snow_presence/tile_h18_v17.zarr',
#  '/tmp/modis_snow_presence/tile_h16_v17.zarr',
#  '/tmp/modis_snow_presence/tile_h19_v17.zarr']

# %%
zarr = xr.open_zarr(files[0])

# %%
zarr.sel(WY=2016)['max_consec_snow_days'].plot()

# %%
# !du -h output/global
# Out:
# 16K	output/global/tile_h15_v17.zarr/spatial_ref
# 24K	output/global/tile_h15_v17.zarr/x
# 776K	output/global/tile_h15_v17.zarr/SAD_DOWY
# 980K	output/global/tile_h15_v17.zarr/max_consec_snow_days
# 16K	output/global/tile_h15_v17.zarr/WY
# 1.1M	output/global/tile_h15_v17.zarr/SDD_DOWY
# 24K	output/global/tile_h15_v17.zarr/y
# 3.0M	output/global/tile_h15_v17.zarr
# 3.0M	output/global
